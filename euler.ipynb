# %% [markdown]
# <a href="https://colab.research.google.com/github/techzzy/F25-MAT-1630/blob/main/euler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import matplotlib.pyplot as plt

h = 0.1
x = 0
y = 1

xs = [x]
ys = [y]

for i in range(30):
    y = y + h * (-x + y)
    x = x + h
    xs.append(x)
    ys.append(y)

x_exact = []
y_exact = []
xx = 0
while xx <= xs[-1]:
    x_exact.append(xx)
    y_exact.append(-xx - 1 + 2 * math.exp(xx))
    xx += 0.01

for i in range(4):
    print("x", i, "=", xs[i], "   y", i, "=", ys[i])

plt.plot(x_exact, y_exact)
plt.plot(xs, ys, "o--")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# x 0 = 0    y 0 = 1
# x 1 = 0.1    y 1 = 1.1
# x 2 = 0.2    y 2 = 1.2000000000000002
# x 3 = 0.30000000000000004    y 3 = 1.3000000000000003
# /tmp/ipython-input-2002127182.py:34: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
